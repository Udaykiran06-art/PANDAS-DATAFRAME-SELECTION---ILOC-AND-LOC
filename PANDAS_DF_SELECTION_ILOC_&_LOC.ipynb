# %% [markdown]
# <a href="https://colab.research.google.com/github/Udaykiran06-art/PANDAS-DATAFRAME-SELECTION---ILOC-AND-LOC/blob/main/PANDAS_DF_SELECTION_ILOC_%26_LOC.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-2e3ca644-d8f8-4623-ab02-329525442634" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-2e3ca644-d8f8-4623-ab02-329525442634">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
#Selecting single column from the DataFrame
import pandas as pd
df = pd.read_csv("sales1.csv")
print(df.Product)
# Out:
# 0      34in Ultrawide Monitor
# 1                 Samsung m10
# 2                20in Monitor
# 3                   iPhone 11
# 4          Macbook Pro Laptop
#                 ...
# 595        Macbook Pro Laptop
# 596           ThinkPad Laptop
# 597             Flatscreen TV
# 598               Samsung m20
# 599        LG Washing Machine
# Name: Product, Length: 600, dtype: object

# %%
#Selecting single column from the DataFrame
import pandas as pd
df = pd.read_csv("sales1.csv")
s = df["Product"]
print(s)
# Out:
# 0      34in Ultrawide Monitor
# 1                 Samsung m10
# 2                20in Monitor
# 3                   iPhone 11
# 4          Macbook Pro Laptop
#                 ...
# 595        Macbook Pro Laptop
# 596           ThinkPad Laptop
# 597             Flatscreen TV
# 598               Samsung m20
# 599        LG Washing Machine
# Name: Product, Length: 600, dtype: object

# %%
#Selecting multiple columns from the Dataframe
import pandas as pd
df1 = pd.read_csv("sales1.csv")
cols = ["Customer Name","Product"]
df2 = df1[cols]
print(df2)
# Out:
#     Customer Name                 Product
# 0           Veeru  34in Ultrawide Monitor
# 1           Tarun             Samsung m10
# 2           Kedar            20in Monitor
# 3         Lavanya               iPhone 11
# 4            Venu      Macbook Pro Laptop
# ..            ...                     ...
# 595        Balaji      Macbook Pro Laptop
# 596       Lavanya         ThinkPad Laptop
# 597          Venu           Flatscreen TV
# 598        Siddhu             Samsung m20
# 599         Tarun      LG Washing Machine
#
# [600 rows x 2 columns]

# %%
#Selecting single column from the DataFrame,apply total
import pandas as pd
df = pd.read_csv("sales1.csv")
total = df['Quantity'].sum()
print(total)
# Out:
# 889

# %%
#Creating a Dataframe by loading csv file
import pandas as pd
df = pd.read_csv("sales1.csv")
print(df)
# Out:
#      Order ID Customer Name                 Product  Quantity
# 0      166837         Veeru  34in Ultrawide Monitor         2
# 1      166838         Tarun             Samsung m10         3
# 2      166839         Kedar            20in Monitor         1
# 3      166840       Lavanya               iPhone 11         3
# 4      166841          Venu      Macbook Pro Laptop         2
# ..        ...           ...                     ...       ...
# 595    167403        Balaji      Macbook Pro Laptop         1
# 596    167404       Lavanya         ThinkPad Laptop         1
# 597    167405          Venu           Flatscreen TV         1
# 598    167406        Siddhu             Samsung m20         2
# 599    167407         Tarun      LG Washing Machine         1
#
# [600 rows x 4 columns]

# %%
#Select specific customer from existing DataFrame
import pandas as pd
df1 = pd.read_csv("sales1.csv")
cust_name = df1["Customer Name"]== "Veeru"
print(df1[cust_name])
# Out:
#      Order ID Customer Name                     Product  Quantity
# 0      166837         Veeru      34in Ultrawide Monitor         2
# 25     166861         Veeru            Wired Headphones         1
# 34     166870         Veeru            Wired Headphones         2
# 61     166897         Veeru        USB-C Charging Cable         2
# 65     166901         Veeru                 Samsung m10         2
# 77     166913         Veeru                    iPhone 9         1
# 85     166920         Veeru                    iPhone 9         2
# 88     166923         Veeru            27in FHD Monitor         1
# 113    166948         Veeru                 Samsung m10         1
# 117    166952         Veeru          LG Washing Machine         2
# 129    166964         Veeru                 Samsung m10         1
# 130    166965         Veeru  Bose SoundSport Headphones         1
# 134    166968         Veeru                    iPhone 7         2
# ...

# %%
#Selecting specific customer from existing Dataframe
import pandas as pd
df1 = pd.read_csv("sales1.csv")
prod_name = df1["Product"]=="Macbook Pro Laptop"
print(df1[prod_name])
# Out:
#      Order ID Customer Name             Product  Quantity
# 4      166841          Venu  Macbook Pro Laptop         2
# 11     166848       Karteek  Macbook Pro Laptop         1
# 15     166851  Jaya Chandra  Macbook Pro Laptop         1
# 71     166907       Karteek  Macbook Pro Laptop         1
# 122    166957        Harsha  Macbook Pro Laptop         2
# 136    166970         Tarun  Macbook Pro Laptop         2
# 156    166986       Pradhan  Macbook Pro Laptop         1
# 184    167013       Sumanth  Macbook Pro Laptop         1
# 190    167019         Veeru  Macbook Pro Laptop         2
# 192    167021   Mallikarjun  Macbook Pro Laptop         1
# 199    167027        Balaji  Macbook Pro Laptop         1
# 225    167050          Venu  Macbook Pro Laptop         2
# 242    167067     Madhurima  Macbook Pro Laptop         2
# 251    167074       Lavanya  Macbook Pro Laptop         1
# 261    167084        Shahid  Macbook Pro Laptop         1
# ...

# %%
#Loading csv file by using pandas
import pandas as pd
df1 = pd.read_csv("sales1.csv")
print(df1.head())
# Out:
#    Order ID Customer Name                 Product  Quantity
# 0    166837         Veeru  34in Ultrawide Monitor         2
# 1    166838         Tarun             Samsung m10         3
# 2    166839         Kedar            20in Monitor         1
# 3    166840       Lavanya               iPhone 11         3
# 4    166841          Venu      Macbook Pro Laptop         2

# %%
#First row of the dataframe
import pandas as pd
df1 = pd.read_csv("sales1.csv")
s = df1.iloc[0]
print(s)
# Out:
# Order ID                         166837
# Customer Name                     Veeru
# Product          34in Ultrawide Monitor
# Quantity                              2
# Name: 0, dtype: object

# %%
#Second row of the DataFrame
import pandas as pd
df1 = pd.read_csv("sales1.csv")
s = df1.iloc[1]
print(s)
# Out:
# Order ID              166838
# Customer Name          Tarun
# Product          Samsung m10
# Quantity                   3
# Name: 1, dtype: object

# %%
#Last row of the Dataframe
import pandas as pd
df1 = pd.read_csv("sales1.csv")
s = df1.iloc[-1]
print(s)
# Out:
# Order ID                     167407
# Customer Name                 Tarun
# Product          LG Washing Machine
# Quantity                          1
# Name: 599, dtype: object

# %%
#First column of the DataFrame
import pandas as pd
df1 = pd.read_csv("sales1.csv")
s = df1.iloc[:,0]
print(s)
# Out:
# 0      166837
# 1      166838
# 2      166839
# 3      166840
# 4      166841
#         ...
# 595    167403
# 596    167404
# 597    167405
# 598    167406
# 599    167407
# Name: Order ID, Length: 600, dtype: int64

# %%
#Second column of the DataFrame
import pandas as pd
df1 = pd.read_csv("sales1.csv")
df2 = df1.iloc[:,1]
print(df2)
# Out:
# 0        Veeru
# 1        Tarun
# 2        Kedar
# 3      Lavanya
# 4         Venu
#         ...
# 595     Balaji
# 596    Lavanya
# 597       Venu
# 598     Siddhu
# 599      Tarun
# Name: Customer Name, Length: 600, dtype: object

# %%
#Last column of the DataFrame
import pandas as pd
df1 = pd.read_csv("sales1.csv")
df2 = df1.iloc[:,-1]
print(df2)
# Out:
# 0      2
# 1      3
# 2      1
# 3      3
# 4      2
#       ..
# 595    1
# 596    1
# 597    1
# 598    2
# 599    1
# Name: Quantity, Length: 600, dtype: int64

# %%
#First five rows from DataFrame
import pandas as pd
df1 = pd.read_csv("sales1.csv")
df2 = df1.iloc[0:5]
print(df2)
# Out:
#    Order ID Customer Name                 Product  Quantity
# 0    166837         Veeru  34in Ultrawide Monitor         2
# 1    166838         Tarun             Samsung m10         3
# 2    166839         Kedar            20in Monitor         1
# 3    166840       Lavanya               iPhone 11         3
# 4    166841          Venu      Macbook Pro Laptop         2

# %%
#First two columns of the Dataframe with all rows
import pandas as pd
df1 = pd.read_csv("sales1.csv")
df2 = df1.iloc[:,0:2]
print(df2)
# Out:
#      Order ID Customer Name
# 0      166837         Veeru
# 1      166838         Tarun
# 2      166839         Kedar
# 3      166840       Lavanya
# 4      166841          Venu
# ..        ...           ...
# 595    167403        Balaji
# 596    167404       Lavanya
# 597    167405          Venu
# 598    167406        Siddhu
# 599    167407         Tarun
#
# [600 rows x 2 columns]

# %%
#First three columns of the dataframe with all rows
import pandas as pd
df1 = pd.read_csv("sales1.csv")
df2 = df1.iloc[:,0:3]
print(df2)
# Out:
#      Order ID Customer Name                 Product
# 0      166837         Veeru  34in Ultrawide Monitor
# 1      166838         Tarun             Samsung m10
# 2      166839         Kedar            20in Monitor
# 3      166840       Lavanya               iPhone 11
# 4      166841          Venu      Macbook Pro Laptop
# ..        ...           ...                     ...
# 595    167403        Balaji      Macbook Pro Laptop
# 596    167404       Lavanya         ThinkPad Laptop
# 597    167405          Venu           Flatscreen TV
# 598    167406        Siddhu             Samsung m20
# 599    167407         Tarun      LG Washing Machine
#
# [600 rows x 3 columns]

# %%
#first 5 rows and first 2 columns of the Dataframe
import pandas as pd
df1 = pd.read_csv("sales1.csv")
df2 = df1.iloc[0:5,0:2]
print(df2)
# Out:
#    Order ID Customer Name
# 0    166837         Veeru
# 1    166838         Tarun
# 2    166839         Kedar
# 3    166840       Lavanya
# 4    166841          Venu

# %%
#first 5 rows and first 3 columns of the Dataframe
import pandas as pd
df1 = pd.read_csv("sales1.csv")
df2 = df1.iloc[0:5,0:3]
print(df1.head())
print()
print(df2)
# Out:
#    Order ID Customer Name                 Product  Quantity
# 0    166837         Veeru  34in Ultrawide Monitor         2
# 1    166838         Tarun             Samsung m10         3
# 2    166839         Kedar            20in Monitor         1
# 3    166840       Lavanya               iPhone 11         3
# 4    166841          Venu      Macbook Pro Laptop         2
#
#    Order ID Customer Name                 Product
# 0    166837         Veeru  34in Ultrawide Monitor
# 1    166838         Tarun             Samsung m10
# 2    166839         Kedar            20in Monitor
# 3    166840       Lavanya               iPhone 11
# 4    166841          Venu      Macbook Pro Laptop

# %%
#Loading csv file
import pandas as pd
df1 = pd.read_csv("sales1.csv")
print(df1.head())
# Out:
#    Order ID Customer Name                 Product  Quantity
# 0    166837         Veeru  34in Ultrawide Monitor         2
# 1    166838         Tarun             Samsung m10         3
# 2    166839         Kedar            20in Monitor         1
# 3    166840       Lavanya               iPhone 11         3
# 4    166841          Venu      Macbook Pro Laptop         2

# %%
#Setting index as a product name and selecting Dataframe
import pandas as pd
df1 = pd.read_csv("sales1.csv")
df1.set_index("Product",inplace=True)
print(df1)
# Out:
#                         Order ID Customer Name  Quantity
# Product
# 34in Ultrawide Monitor    166837         Veeru         2
# Samsung m10               166838         Tarun         3
# 20in Monitor              166839         Kedar         1
# iPhone 11                 166840       Lavanya         3
# Macbook Pro Laptop        166841          Venu         2
# ...                          ...           ...       ...
# Macbook Pro Laptop        167403        Balaji         1
# ThinkPad Laptop           167404       Lavanya         1
# Flatscreen TV             167405          Venu         1
# Samsung m20               167406        Siddhu         2
# LG Washing Machine        167407         Tarun         1
#
# [600 rows x 3 columns]

# %%
#Setting index as a product name and selecting product
import pandas as pd
df1 = pd.read_csv("sales1.csv")
df2 = df1.set_index("Product",inplace=True)
a = 'Macbook Pro Laptop'
df2 = df1.loc[a]
print(df2.head(10))
# Out:
#                     Order ID Customer Name  Quantity
# Product
# Macbook Pro Laptop    166841          Venu         2
# Macbook Pro Laptop    166848       Karteek         1
# Macbook Pro Laptop    166851  Jaya Chandra         1
# Macbook Pro Laptop    166907       Karteek         1
# Macbook Pro Laptop    166957        Harsha         2
# Macbook Pro Laptop    166970         Tarun         2
# Macbook Pro Laptop    166986       Pradhan         1
# Macbook Pro Laptop    167013       Sumanth         1
# Macbook Pro Laptop    167019         Veeru         2
# Macbook Pro Laptop    167021   Mallikarjun         1

# %%
#Setting index as a Product name and selecting product
import pandas as pd
df1 = pd.read_csv("sales1.csv")
df2 = df1.set_index("Product",inplace=True)
a = 'iPhone 11'
df2 = df1.loc[a]
print(df2.head(10))
# Out:
#            Order ID Customer Name  Quantity
# Product
# iPhone 11    166840       Lavanya         3
# iPhone 11    166846        Siddhu         1
# iPhone 11    166858    Chaithanya         1
# iPhone 11    166877       Neelima         1
# iPhone 11    166904       Lavanya         1
# iPhone 11    166925    Chaithanya         2
# iPhone 11    166966       Karteek         1
# iPhone 11    167010    Chaithanya         3
# iPhone 11    167014         Sagar         3
# iPhone 11    167048       Sumanth         1

# %%
#Setting index as a product name and selecting two products
import pandas as pd
df1 = pd.read_csv("sales1.csv")
df2 = df1.set_index("Product",inplace=True)
a = ['Macbook Pro Laptop','iPhone 11']
df2 = df1.loc[a]
print(df2)
# Out:
#                     Order ID Customer Name  Quantity
# Product
# Macbook Pro Laptop    166841          Venu         2
# Macbook Pro Laptop    166848       Karteek         1
# Macbook Pro Laptop    166851  Jaya Chandra         1
# Macbook Pro Laptop    166907       Karteek         1
# Macbook Pro Laptop    166957        Harsha         2
# Macbook Pro Laptop    166970         Tarun         2
# Macbook Pro Laptop    166986       Pradhan         1
# Macbook Pro Laptop    167013       Sumanth         1
# Macbook Pro Laptop    167019         Veeru         2
# Macbook Pro Laptop    167021   Mallikarjun         1
# Macbook Pro Laptop    167027        Balaji         1
# Macbook Pro Laptop    167050          Venu         2
# Macbook Pro Laptop    167067     Madhurima         2
# Macbook Pro Laptop    167074       Lavanya         1
# Macbook Pro Laptop    167084        Shahid         1
# Macbook Pro Laptop    167107  Jaya Chandra         1
# Macbook Pro Laptop    167123       Karteek         1
# ...

# %%
#Setting index as a product name and selecting two products
import pandas as pd
df1 = pd.read_csv("sales1.csv")
df2 = df1.set_index("Product",inplace=True)
a = ['ThinkPad Laptop','Flatscreen TV']
df2 = df1.loc[a]
print(df2)
# Out:
#                  Order ID Customer Name  Quantity
# Product
# ThinkPad Laptop    166849        Shahid         1
# ThinkPad Laptop    166878        Partha         1
# ThinkPad Laptop    166903         Vijay         2
# ThinkPad Laptop    166909       Pradhan         2
# ThinkPad Laptop    166920  Jaya Chandra         2
# ThinkPad Laptop    166954         Vijay         3
# ThinkPad Laptop    166977         Kedar         1
# ThinkPad Laptop    167018        Balaji         1
# ThinkPad Laptop    167039         Venki         1
# ThinkPad Laptop    167068         Kedar         1
# ThinkPad Laptop    167093         Vijay         2
# ThinkPad Laptop    167098         Sagar         1
# ThinkPad Laptop    167150         Tarun         1
# ThinkPad Laptop    167169     Madhurima         1
# ThinkPad Laptop    167189        Partha         2
# ThinkPad Laptop    167235        Balaji         3
# ThinkPad Laptop    167243    Nireekshan         1
# ThinkPad Laptop    167253    Nireekshan         2
# ...

# %%
#Setting index as a product name and selecting a couple products names with Order id and quantity
import pandas as pd
df1 = pd.read_csv("sales1.csv")
df2 = df1.set_index("Product",inplace=True)
a = ['ThinkPad Laptop','Flatscreen TV']
b = ["Order ID","Quantity"]
df2 = df1.loc[a,b]
print(df2)
# Out:
#                  Order ID  Quantity
# Product
# ThinkPad Laptop    166849         1
# ThinkPad Laptop    166878         1
# ThinkPad Laptop    166903         2
# ThinkPad Laptop    166909         2
# ThinkPad Laptop    166920         2
# ThinkPad Laptop    166954         3
# ThinkPad Laptop    166977         1
# ThinkPad Laptop    167018         1
# ThinkPad Laptop    167039         1
# ThinkPad Laptop    167068         1
# ThinkPad Laptop    167093         2
# ThinkPad Laptop    167098         1
# ThinkPad Laptop    167150         1
# ThinkPad Laptop    167169         1
# ThinkPad Laptop    167189         2
# ThinkPad Laptop    167235         3
# ThinkPad Laptop    167243         1
# ThinkPad Laptop    167253         2
# ThinkPad Laptop    167297         1
# ThinkPad Laptop    167329         1
# ThinkPad Laptop    167367         1
# ThinkPad Laptop    167404         1
# Flatscreen TV      166866         2
# Flatscreen TV      166911         1
# Flatscreen TV      166938         3
# ...

# %%
#Setting index as a product name and selecting a couple products names with Order id and customer name
import pandas as pd
df1 = pd.read_csv("sales1.csv")
df2 = df1.set_index("Product",inplace=True)
a = ['ThinkPad Laptop','Flatscreen TV']
b = ["Order ID","Customer Name"]
df2 = df1.loc[a,b]
print(df2)
# Out:
#                  Order ID Customer Name
# Product
# ThinkPad Laptop    166849        Shahid
# ThinkPad Laptop    166878        Partha
# ThinkPad Laptop    166903         Vijay
# ThinkPad Laptop    166909       Pradhan
# ThinkPad Laptop    166920  Jaya Chandra
# ThinkPad Laptop    166954         Vijay
# ThinkPad Laptop    166977         Kedar
# ThinkPad Laptop    167018        Balaji
# ThinkPad Laptop    167039         Venki
# ThinkPad Laptop    167068         Kedar
# ThinkPad Laptop    167093         Vijay
# ThinkPad Laptop    167098         Sagar
# ThinkPad Laptop    167150         Tarun
# ThinkPad Laptop    167169     Madhurima
# ThinkPad Laptop    167189        Partha
# ThinkPad Laptop    167235        Balaji
# ThinkPad Laptop    167243    Nireekshan
# ThinkPad Laptop    167253    Nireekshan
# ThinkPad Laptop    167297        Partha
# ThinkPad Laptop    167329       Karteek
# ThinkPad Laptop    167367       Neelima
# ThinkPad Laptop    167404       Lavanya
# ...

# %%
#Setting index as a product name and selecting a couple products names with all columns between Order id and quantity
import pandas as pd
df1 = pd.read_csv("sales1.csv")
df2 = df1.set_index("Product",inplace=True)
a = ['ThinkPad Laptop','Flatscreen TV']
b = ["Order ID","Quantity"]
df2 = df1.loc[a,"Order ID":"Quantity"]
print(df2)
# Out:
#                  Order ID Customer Name  Quantity
# Product
# ThinkPad Laptop    166849        Shahid         1
# ThinkPad Laptop    166878        Partha         1
# ThinkPad Laptop    166903         Vijay         2
# ThinkPad Laptop    166909       Pradhan         2
# ThinkPad Laptop    166920  Jaya Chandra         2
# ThinkPad Laptop    166954         Vijay         3
# ThinkPad Laptop    166977         Kedar         1
# ThinkPad Laptop    167018        Balaji         1
# ThinkPad Laptop    167039         Venki         1
# ThinkPad Laptop    167068         Kedar         1
# ThinkPad Laptop    167093         Vijay         2
# ThinkPad Laptop    167098         Sagar         1
# ThinkPad Laptop    167150         Tarun         1
# ThinkPad Laptop    167169     Madhurima         1
# ThinkPad Laptop    167189        Partha         2
# ThinkPad Laptop    167235        Balaji         3
# ThinkPad Laptop    167243    Nireekshan         1
# ThinkPad Laptop    167253    Nireekshan         2
# ...

# %%
##Setting index as a product name and selecting a couple products names with Order id and Customer name
import pandas as pd
df1 = pd.read_csv("sales1.csv")
df2 = df1.set_index("Product",inplace=True)
a = ['ThinkPad Laptop','Flatscreen TV']
b = ["Order ID","Customer Name"]
df2 = df1.loc[a,"Order ID":"Customer Name"]
print(df2)
# Out:
#                  Order ID Customer Name
# Product
# ThinkPad Laptop    166849        Shahid
# ThinkPad Laptop    166878        Partha
# ThinkPad Laptop    166903         Vijay
# ThinkPad Laptop    166909       Pradhan
# ThinkPad Laptop    166920  Jaya Chandra
# ThinkPad Laptop    166954         Vijay
# ThinkPad Laptop    166977         Kedar
# ThinkPad Laptop    167018        Balaji
# ThinkPad Laptop    167039         Venki
# ThinkPad Laptop    167068         Kedar
# ThinkPad Laptop    167093         Vijay
# ThinkPad Laptop    167098         Sagar
# ThinkPad Laptop    167150         Tarun
# ThinkPad Laptop    167169     Madhurima
# ThinkPad Laptop    167189        Partha
# ThinkPad Laptop    167235        Balaji
# ThinkPad Laptop    167243    Nireekshan
# ThinkPad Laptop    167253    Nireekshan
# ThinkPad Laptop    167297        Partha
# ThinkPad Laptop    167329       Karteek
# ThinkPad Laptop    167367       Neelima
# ThinkPad Laptop    167404       Lavanya
# ...

# %%
#Selecting rows with specific product with all columns between Order id and quantity
import pandas as pd
df1 = pd.read_csv("sales1.csv")
a = df1["Product"]=='iPhone 11'
df2 = df1.loc[a]
print(df2.head())
# Out:
#     Order ID Customer Name    Product  Quantity
# 3     166840       Lavanya  iPhone 11         3
# 9     166846        Siddhu  iPhone 11         1
# 22    166858    Chaithanya  iPhone 11         1
# 41    166877       Neelima  iPhone 11         1
# 68    166904       Lavanya  iPhone 11         1

# %%
#Selecting rows with specific product with all columns between Order id and quantity
import pandas as pd
df1 = pd.read_csv("sales1.csv")
a = df1["Product"]=='iPhone 11'
df2 = df1.loc[a,"Order ID":"Quantity"]
print(df2.head())
# Out:
#     Order ID Customer Name    Product  Quantity
# 3     166840       Lavanya  iPhone 11         3
# 9     166846        Siddhu  iPhone 11         1
# 22    166858    Chaithanya  iPhone 11         1
# 41    166877       Neelima  iPhone 11         1
# 68    166904       Lavanya  iPhone 11         1

# %%
#Select rows with specific customer with product name and customer name columns
import pandas as pd
df1 = pd.read_csv("sales1.csv")
a = df1["Product"]=='Macbook Pro Laptop'
df2 = df1.loc[a,"Customer Name":"Product"]
print(df2.head())
# Out:
#     Customer Name             Product
# 4            Venu  Macbook Pro Laptop
# 11        Karteek  Macbook Pro Laptop
# 15   Jaya Chandra  Macbook Pro Laptop
# 71        Karteek  Macbook Pro Laptop
# 122        Harsha  Macbook Pro Laptop
